# %% [markdown]
# # JEPA Binpack Training
# This notebook shows how to train the NNUE model with JEPA loss using a `.binpack` dataset that you have downloaded yourself.

# %% [markdown]
# ## 1. Clone the repository

# %%
# !git clone https://github.com/bullardji/nnue-pytorch
# %cd nnue-pytorch

# %% [markdown]
# ## 2. Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Train the network

# %%
# !python train.py "./path/to/dataset.binpack"     --validation-data "./path/to/dataset.binpack"     --gpus 1     --num-workers 4     --batch-size 8096     --features HalfKAv2_hm^     --jepa-weight 0.1     --jepa-mask-mode random     --max_epochs 10
